# %% [markdown]
# UNOPTIMIZED

# %%
def process_order_unop (cust_order, fraud_email):
    blocked_transaction=[]
    for order in cust_order:
        if order["email"] in fraud_email:
            blocked_transaction.append(order["id"])
        return blocked_transaction

# %% [markdown]
# OPTIMIZED

# %%
def process_order_unop (cust_order, fraud_email):
    blocked_transaction=[]
    fraud_set = set(fraud_email)
    for order in cust_order:
        if order["email"] in fraud_email:
            blocked_transaction.append(order["id"])
        return blocked_transaction
